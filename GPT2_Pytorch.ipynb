# %%
# !git clone https://github.com/graykode/gpt-2-Pytorch
# %cd gpt-2-Pytorch
# !curl --output gpt2-pytorch_model.bin https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-pytorch_model.bin
# %pip install -r requirements.txt

# %%
from deep_translator import GoogleTranslator

# %%
# lang = str(input("language (en/id)\t: ")).lower()
# keyword = str(input("Keyword \t: "))

# if lang == "en":
#     !python main.py --text keyword
# elif lang == "id":
#     translator = GoogleTranslator(source='auto', target='en')
#     !python main.py --text translator
# else:
#     print("sorry, we don't know the language")

# %%
word = 'Communist'
# !python main.py --text "global warming"
# Out:
# global warming
# Namespace(text='global warming', quiet=False, nsamples=1, unconditional=False, batch_size=-1, length=-1, temperature=0.7, top_k=40)
# global warming
# ======================================== SAMPLE 1 ========================================
#  and climate change. As climate scientist Richard Holley says in a recent paper in Nature Climate Change, "There's no question that the long-term average temperature has gone up and the long-term average is going down".
#
# We may soon know how much of the planet's surface is covered by a glacier. But that's not the same as knowing how much water is trapped in the ice. As theallah says, "It's about the size of a football field. It's about how much water you get. It is a very large quantity of ice that is being released at a very rapid rate."
#
# ...
